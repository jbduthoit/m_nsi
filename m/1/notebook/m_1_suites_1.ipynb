# %% [markdown]
# # Quelques exos python en lien avec les suites

# %% [markdown]
# ## Exo 1

# %% [markdown]
# On considère la suite $(u_n)$ définie par $u_n=7n-6$. Construire une fonction terme_un(n) qui donne la valeur de $u_n$ pour un $n$ entré en argument.

# %%
def terme_un(n):
    ...

# %%
assert terme_un(0) == -6
assert terme_un(10) == 64
# Out:
# Traceback (most recent call last):
#   File "<input>", line 1, in <module>
# AssertionError

# %% [markdown]
# ## Exo 2

# %% [markdown]
# On considère la suite $(u_n)$ définie par $u_0=7$ et la relation, valable pour tout n∈N, $u_{n+1}=0,6u_n+2$.

# %% [markdown]
# Compléter le programme suivant afin que terme(n) retourne la valeur de $u_n$

# %%
def terme(n):
  u = 7
  for k in range(n) :
    u = ...
  return ...

# %%
assert terme(1) == 6.2
assert terme(5) == 5.155519999999999
assert terme(20) == 5.000073123168801
# Out:
# Traceback (most recent call last):
#   File "<input>", line 1, in <module>
# AssertionError

# %% [markdown]
# ## Exo 3

# %% [markdown]
# Un investisseur particulièrement efficace propose un placement permettant à ses clients d’augmenter leur capital de 5 % par an.
# Un de ses clients place 200 €, puis laisse son argent fructifier.
#
# 1) Compléter la fonction capital afin qu’elle retourne le capital disponible au bout de n années.

# %%
def capital(n):
  c = 200
  for i in range(n):
    c = ...
  return c

# %% [markdown]
# 2) La fonction seuil permet de retourner le nombre d’années nécessaires pour que le capital dépasse 2000 €.

# %%
def seuil():
  c = 200
  n = 0
  while c < 2000:
    c = 1.05*c
    n = n + 1
  return n

# %% [markdown]
# a) Tester et explicier ce programme

# %%
seuil()
# Out:
# 48

# %% [markdown]
# En modifiant le programme, déterminer le nombre d’années nécessaires afin que le capital dépasse 5000 €

# %%
def seuil():
  c = 200
  n = 0
  while c < 2000:
    c = 1.05*c
    n = n + 1
  return n

# %%
seuil()
# Out:
# 48
